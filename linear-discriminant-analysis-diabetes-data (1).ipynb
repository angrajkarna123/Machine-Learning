# %% [markdown]
# # Linear Discriminant Analysis - Diabetes Data

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading Data

# %%
data = pd.read_csv("../input/diabetes-dataset/diabetes2.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Assigning Values to Input and Output Vector

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %% [markdown]
# ### Linear Discriminant Analysis

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
lda = LinearDiscriminantAnalysis()

lda.fit(X, y)
yp= lda.predict(X)

# %%
lda.decision_function(X)
# Out:
# array([ 9.95707475e-01, -3.07489996e+00,  1.52919637e+00, -3.24915975e+00,
#         2.13891281e+00, -1.78439774e+00, -2.74958053e+00,  6.45138838e-01,
#         1.08176621e+00, -3.09382732e+00, -1.41031516e+00,  2.21672382e+00,
#         1.35572594e+00,  7.22804484e-01,  6.51266789e-01, -3.71691574e-01,
#        -6.94412399e-01, -1.46114088e+00, -6.89330822e-01, -1.27353086e+00,
#        -5.43591186e-01, -8.54589443e-01,  2.82293486e+00, -8.82835053e-01,
#         8.87478183e-01, -2.02265698e-01,  1.02043052e+00, -3.10635960e+00,
#         3.14287780e-01, -1.04392728e+00, -3.51419718e-01,  3.20526711e-01,
#        -3.04169599e+00, -3.33517926e+00, -2.37226372e-01, -1.75391481e+00,
#         7.05383731e-01, -4.77070302e-01, -1.73238470e+00,  2.31233637e-01,
#         1.13504278e+00,  7.55569119e-01, -2.05803787e+00,  2.53887486e+00,
#         6.27758210e-01,  2.96555730e+00, -2.57405710e-01, -3.34192798e+00,
# ...

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix = confusion_matrix(y, yp)
print(confusion_matrix)
# Out:
# [[446  54]
#  [112 156]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y, yp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84       500
#            1       0.74      0.58      0.65       268
#
#     accuracy                           0.78       768
#    macro avg       0.77      0.74      0.75       768
# weighted avg       0.78      0.78      0.78       768

# %% [markdown]
# ### I hope you liked my Notebook.
